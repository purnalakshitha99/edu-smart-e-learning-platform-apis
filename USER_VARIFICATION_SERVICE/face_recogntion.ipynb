# %%
import cv2 as cv
import glob, json
import numpy as np
import faiss, glob, os
import tensorflow as tf
from deepface import DeepFace
from matplotlib import pyplot as plt
from PIL import Image, ImageDraw, ImageFont

# %%
models = [
        "VGG-Face", 
        "Facenet", 
        "Facenet512", 
        "OpenFace", 
        "DeepFace", 
        "DeepID", 
        "ArcFace", 
        "Dlib", 
        "SFace",
        "GhostFaceNet",
        ]

# %%
def create_dataset(
                data_dir = "data/facedb/*/*.*",
                json_dir = "data/facedb_jsons/{}/{}",
                ):
    for img_path in glob.glob(data_dir):
        person_objs = []
        img_path = img_path.replace("\\", "/")
        person_name = img_path.split("/")[-2]
        file_name = img_path.split("/")[-1]
        face_objs = DeepFace.represent(
                                    img_path = img_path,
                                    model_name = "Facenet512",
                                    enforce_detection = False
                                    )
        if len(face_objs) > 0:
            for i in range(len(face_objs)):
                person_json = {}
                facial_area = face_objs[i]['facial_area']
                x, y, w, h = facial_area['x'], facial_area['y'], facial_area['w'], facial_area['h']
                person_json['person_name'] = person_name
                person_json['facial_area'] = facial_area
                person_json['file_name'] = file_name
                person_json['coor'] = (x, y, w, h)
                person_objs.append(person_json)

        if len(person_objs) > 0:
            os.makedirs(json_dir.format(person_name, ""), exist_ok=True)
            json_file = json_dir.format(person_name, file_name.replace(".jpg", ".json"))
            with open(json_file, 'w') as json_file:
                json.dump(person_objs, json_file)

# %%
create_dataset()

# %% [markdown]
# ### Detection Model

# %%
def load_detection_dataset(
                            data_dir = "data/facedb/*/*.*"
                            ):
    X, Y = [], []
    for img_path in glob.glob(data_dir):
        json_path = img_path.replace("\\", "/").replace("facedb", "facedb_jsons").replace(".jpg", ".json")
        if (os.path.exists(json_path)):
            with open(json_path, 'r') as json_file:
                json_data = json.load(json_file)
                person = json_data[0]
                x, y, w, h = person['coor']
                img = cv.imread(img_path)
                img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
                img = cv.resize(img, (128, 128))

                X.append(img)
                Y.append((x, y, w, h))

    return np.array(X), np.array(Y)

# %%
X, Y = load_detection_dataset() 

print("Image Shape: ", X.shape)
print("Label Shape: ", Y.shape)
# Out:
# Image Shape:  (439, 128, 128, 3)
# Label Shape:  (439, 4)

# %%
model = tf.keras.models.Sequential([
                                    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
                                    tf.keras.layers.MaxPooling2D((2, 2)),
                                    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
                                    tf.keras.layers.MaxPooling2D((2, 2)),
                                    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
                                    tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(64, activation='relu'),
                                    tf.keras.layers.Dense(4)
                                    ])

model.compile(
                optimizer='adam', 
                loss='mean_squared_error', 
                metrics=['mae']
                )
model.fit(
        X, Y, 
        epochs=200
        )
# Out:
# Epoch 1/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 6s 270ms/step - loss: 181514.1875 - mae: 299.5458
# Epoch 2/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - loss: 115224.7344 - mae: 244.1520
# Epoch 3/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 226ms/step - loss: 106310.4062 - mae: 232.5051
# Epoch 4/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - loss: 91081.1484 - mae: 198.9611
# Epoch 5/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 278ms/step - loss: 49090.3555 - mae: 151.7344
# Epoch 6/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 268ms/step - loss: 52576.9727 - mae: 160.0912
# Epoch 7/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 248ms/step - loss: 33885.7930 - mae: 123.1782
# Epoch 8/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 222ms/step - loss: 21175.7617 - mae: 100.5601
# Epoch 9/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 212ms/step - loss: 16362.6396 - mae: 89.9018
# Epoch 10/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - loss: 10328.5371 - mae: 72.5770
# Epoch 11/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 213ms/step
200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - loss: 8434.2559 - mae: 63.8184
# Epoch 197/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - loss: 6561.4419 - mae: 55.6914
# Epoch 198/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - loss: 3757.5828 - mae: 42.7483
# Epoch 199/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - loss: 3812.8064 - mae: 42.8363
# Epoch 200/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - loss: 2094.5354 - mae: 29.2527

# %%
def visualize_face_detection(img_path):
    face_objs = DeepFace.represent(
                                img_path = img_path,
                                model_name = "Facenet512",
                                enforce_detection = False
                                )
    for i in range(len(face_objs)):
        facial_area = face_objs[i]['facial_area']
        face_confidence = face_objs[i]['face_confidence']
        x, y, w, h = facial_area['x'], facial_area['y'], facial_area['w'], facial_area['h']

        image = Image.open(img_path)
        draw = ImageDraw.Draw(image)
        draw.rectangle([x, y, x+w, y+h], outline='red', width=5)
        font = ImageFont.truetype("arial.ttf", 30)
        draw.text((x-30, y-40), f'Confidence: {face_confidence}', font=font, fill='blue')
        
    plt.imshow(image)

# %%
img_path = "data/facedb/dulaj/dulaj (2).jpg"
visualize_face_detection(img_path)

# %%
def extract_face_information_for_db(img_path):
    # face_objs = DeepFace.represent(
    #                                 img_path = img_path, 
    #                                 detector_backend = backends[4],
    #                                 align = alignment_modes[0],
    #                                 enforce_detection = False
    #                                 )
    face_objs = DeepFace.represent(
                                img_path = img_path,
                                model_name = models[2],
                                enforce_detection = False
                                )
    img_path = img_path.replace("\\", "/")
    user_name = img_path.split("/")[-2]

    if len(face_objs) != 1:
        if len(face_objs) == 0:
            Warning(f"No faces detected in the image : {img_path}")
        else:
            Warning(f"Multiple faces detected in the image : {img_path}")
        return None, None, None, None

    else:
        facial_area = face_objs[0]['facial_area']
        embeddings = face_objs[0]['embedding']
        face_confidence = face_objs[0]['face_confidence']
        x, y, w, h = facial_area['x'], facial_area['y'], facial_area['w'], facial_area['h']

    return embeddings, face_confidence, (x, y, w, h), user_name

def extract_face_information_for_inference(img_path):
    face_objs = DeepFace.represent(
                                img_path = img_path,
                                model_name = models[2],
                                enforce_detection = False
                                )
    img_path = img_path.replace("\\", "/")

    embeddings = []
    facial_areas = []
    face_confidences = []

    if len(face_objs) == 0:
        Warning(f"No faces detected in the image : {img_path}")
    else:
        for i in range(len(face_objs)):
            embs = face_objs[i]['embedding']
            facial_area = face_objs[i]['facial_area']
            face_confidence = face_objs[i]['face_confidence']
            x, y, w, h = facial_area['x'], facial_area['y'], facial_area['w'], facial_area['h']

            embeddings.append(embs)
            facial_areas.append((x, y, w, h))   
            face_confidences.append(face_confidence)

    return embeddings, face_confidences, facial_areas

# %%
def build_face_embedding_index(
                                d = 512,
                                face_index_path = 'models/face_index',
                                face_image_dir = 'data/facedb/*/*.jpg',
                                face_details_path = 'models/face_details.npz',
                                ):
    if (not os.path.exists(face_index_path)) or (not os.path.exists(face_details_path)):
        faiss_index = faiss.index_factory(d, "Flat", faiss.METRIC_INNER_PRODUCT)

        embeddings = []
        user_names = []
        facial_areas = []
        face_confidences = []
        
        for idx, img_path in enumerate(glob.glob(face_image_dir)):
            emb, face_confidence, facial_area, user_name = extract_face_information_for_db(img_path)
            if emb is not None:
                embeddings.append(emb)
                user_names.append(user_name)
                facial_areas.append(facial_area)
                face_confidences.append(face_confidence)

            if idx % 10 == 0:
                print(f"Processed {idx}/{len(glob.glob(face_image_dir))} images")

        embeddings = np.asarray(embeddings).astype('float32')
        faiss.normalize_L2(embeddings)
        faiss_index.add(embeddings)
        faiss.write_index(faiss_index, face_index_path)

        np.savez(
                face_details_path, 
                user_names=user_names, 
                facial_areas=facial_areas, 
                face_confidences=face_confidences
                )
        
    else:
        faiss_index = faiss.read_index(face_index_path)
        face_details = np.load(face_details_path)
        user_names = face_details['user_names']
        facial_areas = face_details['facial_areas']
        face_confidences = face_details['face_confidences']

    return faiss_index, user_names, facial_areas, face_confidences

# %%
index, user_names, facial_areas, face_confidences = build_face_embedding_index()

# %%
def add_user_to_db(
                    username, 
                    face_index_path = 'models/face_index',
                    face_details_path = 'models/face_details.npz',
                    face_image_dir = 'data/facedb/{}/*.jpg'
                    ):
    index, user_names, facial_areas, face_confidences = build_face_embedding_index(
                                                                                    face_index_path = face_index_path,
                                                                                    face_details_path = face_details_path,
                                                                                    )
    if username in user_names:
        Warning(f"User {username} already exists in the database")
        return
    
    user_names_to_add = []
    facial_areas_to_add = []
    face_confidences_to_add = []

    for img_path in glob.glob(face_image_dir.format(username)):
        emb, face_confidence, facial_area, user_name = extract_face_information_for_db(img_path)
        if emb is not None:
            embeddings = np.array([emb]).astype('float32')
            faiss.normalize_L2(embeddings)
            index.add(embeddings)
            user_names_to_add.append(user_name)
            facial_areas_to_add.append(facial_area)
            face_confidences_to_add.append(face_confidence)

    faiss.write_index(index, face_index_path)

    if len(user_names_to_add) > 0:
        user_names = np.concatenate([user_names, user_names_to_add])
        facial_areas = np.concatenate([facial_areas, facial_areas_to_add])
        face_confidences = np.concatenate([face_confidences, face_confidences_to_add])

    np.savez(
            face_details_path, 
            user_names=user_names, 
            facial_areas=facial_areas, 
            face_confidences=face_confidences
            )
    
    print(f"User : {username} added to the database")

def search_face_in_db(
                    img_path, 
                    face_index_path = 'models/face_index',
                    face_details_path = 'models/face_details.npz',
                    ):
    index, user_names, _, _ = build_face_embedding_index(
                                                        face_index_path = face_index_path,
                                                        face_details_path = face_details_path,
                                                        )
    embeddings, face_confidences, facial_areas = extract_face_information_for_inference(img_path)

    retrieved_user_names = []
    retrieved_facial_areas = []
    retrieved_face_confidences = []

    if embeddings is not None:
        for idx, emb in enumerate(embeddings):
            if face_confidences[idx] >= 0.8:
                emb = np.array(emb).reshape(1, -1).astype('float32')
                faiss.normalize_L2(emb)
                D, I = index.search(emb, 5)
                I = np.array(I).squeeze()
                D = np.array(D).squeeze()
                user_name_list = [user_names[i] for i in I]
                user_name = max(set(user_name_list), key = user_name_list.count)
                avg_confidence = np.mean([d for i, d in zip(I, D) if user_names[i] == user_name])
                retrieved_face_confidences.append(np.round(avg_confidence, 3))
                retrieved_facial_areas.append(facial_areas[idx])
                retrieved_user_names.append(user_name)

    return retrieved_user_names, retrieved_facial_areas, retrieved_face_confidences

def verify_and_visualize_user(  
                                username,
                                img_path,
                                ):
    retrieved_user_names, retrieved_facial_areas, retrieved_face_confidences = search_face_in_db(img_path)

    image = Image.open(img_path)
    draw = ImageDraw.Draw(image)

    for i in range(len(retrieved_user_names)):
        x, y, w, h = retrieved_facial_areas[i]
        face_area = w * h
        if (face_area >= 20000):
            if (retrieved_user_names[i] == username) and (retrieved_face_confidences[i] >= 0.5):
                draw.rectangle([x, y, x+w, y+h], outline='green', width=5)
                font = ImageFont.truetype("arial.ttf", 30)
                draw.text((x-30, y-70), f'User: {retrieved_user_names[i]}', font=font, fill='green')
            else:
                draw.rectangle([x, y, x+w, y+h], outline='red', width=5)
                font = ImageFont.truetype("arial.ttf", 30)

    plt.imshow(image)
    plt.show()

def verify_and_visualize_user_realtime(username):
    cap = cv.VideoCapture(0)
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        cv.imwrite("data/temp_dir/temp.jpg", frame)
        
        retrieved_user_names, retrieved_facial_areas, retrieved_face_confidences = search_face_in_db("data/temp_dir/temp.jpg")
        for i in range(len(retrieved_user_names)):
            x, y, w, h = retrieved_facial_areas[i]
            face_area = w * h
            if (face_area >= 20000):
                if (retrieved_user_names[i] == username) and (retrieved_face_confidences[i] >= 0.5):
                    cv.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
                    font = cv.FONT_HERSHEY_SIMPLEX
                    cv.putText(frame, f'User: {retrieved_user_names[i]}', (x-30, y-40), font, 1, (0, 255, 0), 2)
                else:
                    cv.rectangle(frame, (x, y), (x+w, y+h), (0, 0, 255), 2)

        cv.imshow('frame', frame)

        if cv.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv.destroyAllWindows()

# %%
add_user_to_db('dulaj')
# Out:
# User : dulaj added to the database

# %%
retrieved_user_names, retrieved_facial_areas, retrieved_face_confidences = search_face_in_db(img_path)

print(f"Retrieve User Names : {retrieved_user_names}")
print(f"Retrieve Face Confidences : {retrieved_face_confidences}")
print(f"Retrieve Facial Areas : {retrieved_facial_areas}")
# Out:
# Retrieve User Names : [np.str_('dulaj')]
# Retrieve Face Confidences : [np.float32(0.949)]
# Retrieve Facial Areas : [(883, 1381, 1272, 1272)]

# %%
verify_and_visualize_user("dulaj", 'data/test_images/dulaj (2).jpg')

# %%
verify_and_visualize_user_realtime("dulaj")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26404\827041166.py in ?()
# ----> 1 verify_and_visualize_user_realtime("dulaj")
#
# ~\AppData\Local\Temp\ipykernel_26404\2413584820.py in ?(username)
#     106             break
#     107
#     108         cv.imwrite("data/temp_dir/temp.jpg", frame)
#     109
# --> 110         retrieved_user_names, retrieved_facial_areas, retrieved_face_confidences = search_face_in_db("data/temp_dir/temp.jpg")
#     111         for i in range(len(retrieved_user_names)):
#     112             x, y, w, h = retrieved_facial_areas[i]
#     113             face_area = w * h
#
# ~\AppData\Local\Temp\ipykernel_26404\2413584820.py in ?(img_path, face_index_path, face_details_path)
#      50     index, user_names, _, _ = build_face_embedding_index(
#      51                                                         face_index_path = face_index_path,
#      52                                                         face_details_path = face_details_path,
#      53                                                         )
# ---> 54     embeddings, face_confidences, facial_areas = extract_face_information_for_inference(img_path)
#      55
#      56     retrieved_user_names = []
#      57     retrieved_facial_areas = []
#
# ~\AppData\Local\Temp\ipykernel_26404\2418822265.py in ?(img_path)
#      31 def extract_face_information_for_inference(img_path):
# ---> 32     face_objs = DeepFace.represent(
#      33                                 img_path = img_path,
#      34                                 model_name = models[2],
#      35                                 enforce_detection = False
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\deepface\DeepFace.py in ?(img_path, model_name, enforce_detection, detector_backend, align, expand_percentage, normalization, anti_spoofing, max_faces)
#     414
#     415         - face_confidence (float): Confidence score of face detection. If `detector_backend` is set
#     416             to 'skip', the confidence will be 0 and is nonsensical.
#     417     """
# --> 418     return representation.represent(
#     419         img_path=img_path,
#     420         model_name=model_name,
#     421         enforce_detection=enforce_detection,
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\deepface\modules\representation.py in ?(img_path, model_name, enforce_detection, detector_backend, align, expand_percentage, normalization, anti_spoofing, max_faces)
#     129
#     130         # custom normalization
#     131         img = preprocessing.normalize_input(img=img, normalization=normalization)
#     132
# --> 133         embedding = model.forward(img)
#     134
#     135         resp_objs.append(
#     136             {
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\deepface\models\FacialRecognition.py in ?(self, img)
#      25                 f"but {self.model_name} not overwritten!"
#      26             )
#      27         # model.predict causes memory issue when it is called in a for loop
#      28         # embedding = model.predict(img, verbose=0)[0].tolist()
# ---> 29         return self.model(img, training=False).numpy()[0].tolist()
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\keras\src\layers\layer.py in ?(self, *args, **kwargs)
#     945                     "layers will not see the mask."
#     946                 )
#     947         finally:
#     948             # Destroy call context if we created it
# --> 949             self._maybe_reset_call_context()
#     950         return outputs
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\keras\src\ops\operation.py in ?(self, *args, **kwargs)
#      54             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      55                 call_fn,
#      56                 object_name=(f"{self.__class__.__name__}.call()"),
#      57             )
# ---> 58             return call_fn(*args, **kwargs)
#      59
#      60         # Plain flow.
#      61         if any_symbolic_tensors(args, kwargs):
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\keras\src\models\functional.py in ?(self, inputs, training, mask)
#     179             masks = tree.flatten(mask)
#     180             for x, mask in zip(inputs, masks):
#     181                 if mask is not None:
#     182                     backend.set_keras_mask(x, mask)
# --> 183         outputs = self._run_through_graph(
#     184             inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     185         )
#     186         return unpack_singleton(outputs)
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\keras\src\ops\function.py in ?(self, inputs, operation_fn, call_fn)
#     167                 op = operation_fn(node.operation)
#     168                 if call_fn is not None:
#     169                     outputs = call_fn(op, *args, **kwargs)
#     170                 else:
# --> 171                     outputs = op(*args, **kwargs)
#     172
#     173                 # Update tensor_dict.
#     174                 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\keras\src\models\functional.py in ?(*args, **kwargs)
#     639             and operation._call_has_training_arg
#     640             and training is not None
#     641         ):
#     642             kwargs["training"] = training
# --> 643         return operation(*args, **kwargs)
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\keras\src\layers\layer.py in ?(self, *args, **kwargs)
#     945                     "layers will not see the mask."
#     946                 )
#     947         finally:
#     948             # Destroy call context if we created it
# --> 949             self._maybe_reset_call_context()
#     950         return outputs
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\keras\src\ops\operation.py in ?(self, *args, **kwargs)
#      54             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      55                 call_fn,
#      56                 object_name=(f"{self.__class__.__name__}.call()"),
#      57             )
# ---> 58             return call_fn(*args, **kwargs)
#      59
#      60         # Plain flow.
#      61         if any_symbolic_tensors(args, kwargs):
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\keras\src\layers\normalization\batch_normalization.py in ?(self, inputs, training, mask)
#     274             beta = ops.cast(self.beta, inputs.dtype)
#     275         else:
#     276             beta = None
#     277
# --> 278         outputs = ops.batch_normalization(
#     279             x=inputs,
#     280             mean=mean,
#     281             variance=variance,
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\keras\src\ops\nn.py in ?(x, mean, variance, axis, offset, scale, epsilon)
#    2201         return BatchNorm(axis, epsilon).symbolic_call(
#    2202             x, mean, variance, offset, scale
#    2203         )
#    2204
# -> 2205     return backend.nn.batch_normalization(
#    2206         x, mean, variance, axis, offset, scale, epsilon
#    2207     )
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\keras\src\backend\tensorflow\nn.py in ?(x, mean, variance, axis, offset, scale, epsilon)
#     866             offset = tf.reshape(offset, shape)
#     867         if scale is not None:
#     868             scale = tf.reshape(scale, shape)
#     869
# --> 870     return tf.nn.batch_normalization(
#     871         x=x,
#     872         mean=mean,
#     873         variance=variance,
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\tensorflow\python\ops\nn_impl.py in ?(x, mean, variance, offset, scale, variance_epsilon, name)
#    1484       inv *= scale
#    1485     # Note: tensorflow/contrib/quantize/python/fold_batch_norms.py depends on
#    1486     # the precise order of ops that are generated by the expression below.
#    1487     return x * math_ops.cast(inv, x.dtype) + math_ops.cast(
# -> 1488         offset - mean * inv if offset is not None else -mean * inv, x.dtype)
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\tensorflow\python\framework\override_binary_operator.py in ?(x, y)
#     110         # TODO(b/178860388): Figure out why binary_op_wrapper and
#     111         #   r_binary_op_wrapper use different force_same_dtype values.
#     112         x, y = maybe_promote_tensors(x, y)
#     113         return func(x, y, name=name)
# --> 114       except (TypeError, ValueError) as e:
#     115         # Even if dispatching the op failed, the RHS may be a tensor aware
#     116         # object that can implement the operator with knowledge of itself
#     117         # and the tensor.
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\tensorflow\python\ops\tensor_math_operator_overrides.py in ?(x, y, name)
#      72             name=name,
#      73         ),
#      74         dtypes.bool,
#      75     )  # pylint: disable=protected-access
# ---> 76   return math_ops._mul_dispatch(x, y, name=name)  # pylint: disable=protected-access
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\tensorflow\python\ops\math_ops.py in ?(x, y, name)
#    1744     new_vals = gen_sparse_ops.sparse_dense_cwise_mul(y.indices, y.values,
#    1745                                                      y.dense_shape, x, name)
#    1746     return sparse_tensor.SparseTensor(y.indices, new_vals, y.dense_shape)
#    1747   else:
# -> 1748     return multiply(x, y, name=name)
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py in ?(*args, **kwargs)
#     140   def wrapper(*args, **kwargs):
#     141     if not ops.is_auto_dtype_conversion_enabled():
# --> 142       return op(*args, **kwargs)
#     143     bound_arguments = signature.bind(*args, **kwargs)
#     144     bound_arguments.apply_defaults()
#     145     bound_kwargs = bound_arguments.arguments
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\tensorflow\python\ops\math_ops.py in ?(x, y, name)
#     522
#     523    * InvalidArgumentError: When `x` and `y` have incompatible shapes or types.
#     524   """
#     525
# --> 526   return gen_math_ops.mul(x, y, name)
#
# c:\Users\PurnaLakshitha\Desktop\edu-smart-e-learning-platfrom-apis\.conda\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in ?(x, y, name)
#    6825         _ctx, "Mul", name, x, y)
#    6826       return _result
#    6827     except _core._NotOkStatusException as e:
#    6828       _ops.raise_from_not_ok_status(e, name)
# -> 6829     except _core._FallbackException:
#    6830       pass
#    6831     try:
#    6832       return mul_eager_fallback(
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
