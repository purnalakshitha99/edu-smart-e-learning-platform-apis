# %%
import cv2 as cv
import glob, json
import numpy as np
import faiss, glob, os
import tensorflow as tf
from deepface import DeepFace
from matplotlib import pyplot as plt
from PIL import Image, ImageDraw, ImageFont

# %%
models = [
        "VGG-Face", 
        "Facenet", 
        "OpenFace", 
        "DeepFace", 
        "DeepID", 
        "ArcFace", 
        "Dlib", 
        "SFace",
        "GhostFaceNet",
        ]

# %%
def create_dataset(
                data_dir = "data/facedb/*/*.*",
                json_dir = "data/facedb_jsons/{}/{}",
                ):
    for img_path in glob.glob(data_dir):
        person_objs = []
        img_path = img_path.replace("\\", "/")
        person_name = img_path.split("/")[-2]
        file_name = img_path.split("/")[-1]
        face_objs = DeepFace.represent(
                                    img_path = img_path,
                                    model_name = "Facenet512",
                                    enforce_detection = False
                                    )
        if len(face_objs) > 0:
            for i in range(len(face_objs)):
                person_json = {}
                facial_area = face_objs[i]['facial_area']
                x, y, w, h = facial_area['x'], facial_area['y'], facial_area['w'], facial_area['h']
                person_json['person_name'] = person_name
                person_json['facial_area'] = facial_area
                person_json['file_name'] = file_name
                person_json['coor'] = (x, y, w, h)
                person_objs.append(person_json)

        if len(person_objs) > 0:
            os.makedirs(json_dir.format(person_name, ""), exist_ok=True)
            json_file = json_dir.format(person_name, file_name.replace(".jpg", ".json"))
            with open(json_file, 'w') as json_file:
                json.dump(person_objs, json_file)

# %%
create_dataset()

# %% [markdown]
# ### Detection Model

# %%
def load_detection_dataset(
                            data_dir = "data/facedb/*/*.*"
                            ):
    X, Y = [], []
    for img_path in glob.glob(data_dir):
        json_path = img_path.replace("\\", "/").replace("facedb", "facedb_jsons").replace(".jpg", ".json")
        if (os.path.exists(json_path)):
            with open(json_path, 'r') as json_file:
                json_data = json.load(json_file)
                person = json_data[0]
                x, y, w, h = person['coor']
                img = cv.imread(img_path)
                img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
                img = cv.resize(img, (128, 128))

                X.append(img)
                Y.append((x, y, w, h))

    return np.array(X), np.array(Y)

# %%
X, Y = load_detection_dataset() 

print("Image Shape: ", X.shape)
print("Label Shape: ", Y.shape)
# Out:
# Image Shape:  (388, 128, 128, 3)
# Label Shape:  (388, 4)

# %%
model = tf.keras.models.Sequential([
                                    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
                                    tf.keras.layers.MaxPooling2D((2, 2)),
                                    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
                                    tf.keras.layers.MaxPooling2D((2, 2)),
                                    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
                                    tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(64, activation='relu'),
                                    tf.keras.layers.Dense(4)
                                    ])

model.compile(
                optimizer='adam', 
                loss='mean_squared_error', 
                metrics=['mae']
                )
model.fit(
        X, Y, 
        epochs=200
        )
# Out:
# Epoch 1/200
# 13/13 [==============================] - 5s 341ms/step - loss: 274761.1250 - mae: 374.5240
# Epoch 2/200
# 13/13 [==============================] - 4s 285ms/step - loss: 145501.9219 - mae: 275.8177
# Epoch 3/200
# 13/13 [==============================] - 4s 308ms/step - loss: 142006.2500 - mae: 273.2735
# Epoch 4/200
# 13/13 [==============================] - 3s 260ms/step - loss: 135918.4688 - mae: 261.5818
# Epoch 5/200
# 13/13 [==============================] - 3s 265ms/step - loss: 125687.5391 - mae: 252.8759
# Epoch 6/200
# 13/13 [==============================] - 4s 282ms/step - loss: 103631.8281 - mae: 229.4175
# Epoch 183/200
# 13/13 [==============================] - 5s 388ms/step - loss: 4515.3828 - mae: 47.6282
# Epoch 184/200
# 13/13 [==============================] - 5s 359ms/step - loss: 2799.6372 - mae: 37.1984
# Epoch 185/200
# 13/13 [==============================] - 5s 374ms/step - loss: 1408.2395 - mae: 26.7326
# Epoch 186/200
# 13/13 [==============================] - 5s 364ms/step - loss: 1488.7395 - mae: 26.3025
# Epoch 187/200
# 13/13 [==============================] - 5s 407ms/step - loss: 1229.3585 - mae: 23.9883
# Epoch 188/200
# 13/13 [==============================] - 5s 362ms/step - loss: 1119.2926 - mae: 23.2165
# Epoch 189/200
# 13/13 [==============================] - 5s 366ms/step - loss: 494.3252 - mae: 15.5791
# Epoch 190/200
# 13/13 [==============================] - 5s 350ms/step - loss: 343.6221 - mae: 13.1718
# Epoch 191/200
# 13/13 [==============================] - 4s 280ms/step - loss: 273.2874 - mae: 11.1534
# Epoch 192/200
# 13/13 [==============================] - 4s 282ms/step - loss: 263.0269 - mae: 10.9542
# Epoch 193/200
# 13/13 [==============================] - 4s 292ms/step - loss: 227.9163 - mae: 9.8505
# Epoch 194/200
# 13/13 [==============================] - 4s 276ms/step - loss: 217.6445 - mae: 9.5761
# Epoch 195/200
# 13/13 [==============================] - 4s 269ms/step - loss: 176.9683 - mae: 8.6392
# Epoch 196/200
# 13/13 [==============================] - 3s 260ms/step - loss: 128.5690 - mae: 7.1797
# Epoch 197/200
# 13/13 [==============================] - 3s 262ms/step - loss: 106.6344 - mae: 6.1662
# Epoch 198/200
# 13/13 [==============================] - 3s 257ms/step - loss: 90.9462 - mae: 5.4122
# Epoch 199/200
# 13/13 [==============================] - 3s 266ms/step - loss: 86.7965 - mae: 5.1016
# Epoch 200/200
# 13/13 [==============================] - 3s 260ms/step - loss: 84.0622 - mae: 5.0302

# %%
def visualize_face_detection(img_path):
    face_objs = DeepFace.represent(
                                img_path = img_path,
                                model_name = "Facenet512",
                                enforce_detection = False
                                )
    for i in range(len(face_objs)):
        facial_area = face_objs[i]['facial_area']
        face_confidence = face_objs[i]['face_confidence']
        x, y, w, h = facial_area['x'], facial_area['y'], facial_area['w'], facial_area['h']

        image = Image.open(img_path)
        draw = ImageDraw.Draw(image)
        draw.rectangle([x, y, x+w, y+h], outline='red', width=5)
        font = ImageFont.truetype("arial.ttf", 30)
        draw.text((x-30, y-40), f'Confidence: {face_confidence}', font=font, fill='blue')
        
    plt.imshow(image)

# %%
img_path = "data/facedb/shanilka/shanilka (5).jpg"
visualize_face_detection(img_path)

# %%
def extract_face_information_for_db(img_path):
    # face_objs = DeepFace.represent(
    #                                 img_path = img_path, 
    #                                 detector_backend = backends[4],
    #                                 align = alignment_modes[0],
    #                                 enforce_detection = False
    #                                 )
    face_objs = DeepFace.represent(
                                img_path = img_path,
                                model_name = models[2],
                                enforce_detection = False
                                )
    img_path = img_path.replace("\\", "/")
    user_name = img_path.split("/")[-2]

    if len(face_objs) != 1:
        if len(face_objs) == 0:
            Warning(f"No faces detected in the image : {img_path}")
        else:
            Warning(f"Multiple faces detected in the image : {img_path}")
        return None, None, None, None

    else:
        facial_area = face_objs[0]['facial_area']
        embeddings = face_objs[0]['embedding']
        print(f"Embedding dimension for {img_path}: {len(embeddings)}")
        face_confidence = face_objs[0]['face_confidence']
        x, y, w, h = facial_area['x'], facial_area['y'], facial_area['w'], facial_area['h']

    return embeddings, face_confidence, (x, y, w, h), user_name

def extract_face_information_for_inference(img_path):
    face_objs = DeepFace.represent(
                                img_path = img_path,
                                model_name = models[2],
                                enforce_detection = False
                                )
    img_path = img_path.replace("\\", "/")

    embeddings = []
    facial_areas = []
    face_confidences = []

    if len(face_objs) == 0:
        Warning(f"No faces detected in the image : {img_path}")
    else:
        for i in range(len(face_objs)):
            embs = face_objs[i]['embedding']
            facial_area = face_objs[i]['facial_area']
            face_confidence = face_objs[i]['face_confidence']
            x, y, w, h = facial_area['x'], facial_area['y'], facial_area['w'], facial_area['h']

            embeddings.append(embs)
            facial_areas.append((x, y, w, h))   
            face_confidences.append(face_confidence)

    return embeddings, face_confidences, facial_areas

# %%
def build_face_embedding_index(
                                d = 128,
                                face_index_path = 'models/face_index',
                                face_image_dir = 'data/facedb/*/*.jpg',
                                face_details_path = 'models/face_details.npz',
                                ):
    if (not os.path.exists(face_index_path)) or (not os.path.exists(face_details_path)):
        faiss_index = faiss.index_factory(d, "Flat", faiss.METRIC_INNER_PRODUCT)

        embeddings = []
        user_names = []
        facial_areas = []
        face_confidences = []
        
        for idx, img_path in enumerate(glob.glob(face_image_dir)):
            emb, face_confidence, facial_area, user_name = extract_face_information_for_db(img_path)
            if emb is not None:
                embeddings.append(emb)
                user_names.append(user_name)
                facial_areas.append(facial_area)
                face_confidences.append(face_confidence)

            if idx % 10 == 0:
                print(f"Processed {idx}/{len(glob.glob(face_image_dir))} images")

        embeddings = np.asarray(embeddings).astype('float32')
        faiss.normalize_L2(embeddings)
        faiss_index.add(embeddings)
        faiss.write_index(faiss_index, face_index_path)

        np.savez(
                face_details_path, 
                user_names=user_names, 
                facial_areas=facial_areas, 
                face_confidences=face_confidences
                )
        
    else:
        faiss_index = faiss.read_index(face_index_path)
        face_details = np.load(face_details_path)
        user_names = face_details['user_names']
        facial_areas = face_details['facial_areas']
        face_confidences = face_details['face_confidences']

    return faiss_index, user_names, facial_areas, face_confidences

# %%
index, user_names, facial_areas, face_confidences = build_face_embedding_index()
# Out:
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_0.jpg: 128
# Processed 0/378 images
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_1.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_10.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_11.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_12.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_14.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_15.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_16.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_17.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_18.jpg: 128
# Processed 10/378 images
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_19.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_2.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_20.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_22.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_23.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_24.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_25.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_27.jpg: 128
# Processed 20/378 images
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_28.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_3.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_30.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_31.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_33.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_34.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_35.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_36.jpg: 128
# Processed 30/378 images
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_38.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_39.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_4.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_40.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_41.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_42.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_43.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_44.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_45.jpg: 128
# Processed 40/378 images
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_47.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_48.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_49.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_5.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_50.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_51.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_52.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_53.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_54.jpg: 128
# Processed 50/378 images
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_55.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_56.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_57.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_58.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_59.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_6.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_60.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_61.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_62.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_63.jpg: 128
# Processed 60/378 images
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_65.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_66.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario_67.jpg: 128
# Embedding dimension for data/facedb/Alexandra Daddario/Alexandra Daddario
# Embedding dimension for data/facedb/Andy Samberg/Andy Samberg_87.jpg: 128
# Embedding dimension for data/facedb/Andy Samberg/Andy Samberg_89.jpg: 128
# Embedding dimension for data/facedb/Andy Samberg/Andy Samberg_9.jpg: 128
# Embedding dimension for data/facedb/Andy Samberg/Andy Samberg_90.jpg: 128
# Embedding dimension for data/facedb/Andy Samberg/Andy Samberg_91.jpg: 128
# Embedding dimension for data/facedb/dulaj/dulaj (1).jpg: 128
# Embedding dimension for data/facedb/dulaj/dulaj (2).jpg: 128
# Embedding dimension for data/facedb/dulaj/dulaj (3).jpg: 128
# Embedding dimension for data/facedb/dulaj/dulaj (4).jpg: 128
# Processed 340/378 images
# Embedding dimension for data/facedb/dulaj/dulaj (5).jpg: 128
# Embedding dimension for data/facedb/dulaj/dulaj (6).jpg: 128
# Embedding dimension for data/facedb/dulaj/dulaj (8).jpg: 128
# Embedding dimension for data/facedb/Isuru Alagiyawanna/IMG-20240804-WA0001.jpg: 128
# Embedding dimension for data/facedb/Isuru Alagiyawanna/IMG-20240804-WA0002.jpg: 128
# Embedding dimension for data/facedb/Isuru Alagiyawanna/IMG-20240804-WA0003.jpg: 128
# Embedding dimension for data/facedb/Isuru Alagiyawanna/IMG-20240804-WA0004.jpg: 128
# Embedding dimension for data/facedb/Isuru Alagiyawanna/IMG-20240804-WA0005.jpg: 128
# Embedding dimension for data/facedb/Isuru Alagiyawanna/IMG-20240804-WA0006.jpg: 128
# Processed 350/378 images
# Embedding dimension for data/facedb/purna/purna (10).jpg: 128
# Embedding dimension for data/facedb/purna/purna (6).jpg: 128
# Embedding dimension for data/facedb/purna/purna (8).jpg: 128
# Embedding dimension for data/facedb/purna/purna (9).jpg: 128
# Processed 360/378 images
# Embedding dimension for data/facedb/sasida/sasida (1).jpg: 128
# Embedding dimension for data/facedb/sasida/sasida (10).jpg: 128
# Embedding dimension for data/facedb/sasida/sasida (2).jpg: 128
# Embedding dimension for data/facedb/sasida/sasida (3).jpg: 128
# Embedding dimension for data/facedb/sasida/sasida (4).jpg: 128
# Embedding dimension for data/facedb/sasida/sasida (5).jpg: 128
# Embedding dimension for data/facedb/sasida/sasida (6).jpg: 128
# Embedding dimension for data/facedb/sasida/sasida (7).jpg: 128
# Embedding dimension for data/facedb/sasida/sasida (8).jpg: 128
# Embedding dimension for data/facedb/sasida/sasida (9).jpg: 128
# Processed 370/378 images
# Embedding dimension for data/facedb/shanilka/shanilka (1).jpg: 128
# Embedding dimension for data/facedb/shanilka/shanilka (2).jpg: 128
# Embedding dimension for data/facedb/shanilka/shanilka (3).jpg: 128
# Embedding dimension for data/facedb/shanilka/shanilka (4).jpg: 128
# Embedding dimension for data/facedb/shanilka/shanilka (5).jpg: 128
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 index, user_names, facial_areas, face_confidences = build_face_embedding_index()
#
# Cell In[31], line 28, in build_face_embedding_index(d, face_index_path, face_image_dir, face_details_path)
#      26 embeddings = np.asarray(embeddings).astype('float32')
#      27 faiss.normalize_L2(embeddings)
# ---> 28 faiss_index.add(embeddings)
#      29 faiss.write_index(faiss_index, face_index_path)
#      31 np.savez(
#      32         face_details_path,
#      33         user_names=user_names,
#      34         facial_areas=facial_areas,
#      35         face_confidences=face_confidences
#      36         )
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\faiss\class_wrappers.py:228, in handle_Index.<locals>.replacement_add(self, x)
#     215 """Adds vectors to the index.
#     216 The index must be trained before vectors can be added to it.
#     217 The vectors are implicitly numbered in sequence. When `n` vectors are
#    (...)
#     224     `dtype` must be float32.
#     225 """
#     227 n, d = x.shape
# --> 228 assert d == self.d
#     229 x = np.ascontiguousarray(x, dtype='float32')
#     230 self.add_c(n, swig_ptr(x))
#
# AssertionError:

# %%
def add_user_to_db(
                    username, 
                    face_index_path = 'models/face_index',
                    face_details_path = 'models/face_details.npz',
                    face_image_dir = 'data/facedb/{}/*.jpg'
                    ):
    index, user_names, facial_areas, face_confidences = build_face_embedding_index(
                                                                                    face_index_path = face_index_path,
                                                                                    face_details_path = face_details_path,
                                                                                    )
    if username in user_names:
        Warning(f"User {username} already exists in the database")
        return
    
    user_names_to_add = []
    facial_areas_to_add = []
    face_confidences_to_add = []

    for img_path in glob.glob(face_image_dir.format(username)):
        emb, face_confidence, facial_area, user_name = extract_face_information_for_db(img_path)
        if emb is not None:
            embeddings = np.array([emb]).astype('float32')
            faiss.normalize_L2(embeddings)
            index.add(embeddings)
            user_names_to_add.append(user_name)
            facial_areas_to_add.append(facial_area)
            face_confidences_to_add.append(face_confidence)

    faiss.write_index(index, face_index_path)

    if len(user_names_to_add) > 0:
        user_names = np.concatenate([user_names, user_names_to_add])
        facial_areas = np.concatenate([facial_areas, facial_areas_to_add])
        face_confidences = np.concatenate([face_confidences, face_confidences_to_add])

    np.savez(
            face_details_path, 
            user_names=user_names, 
            facial_areas=facial_areas, 
            face_confidences=face_confidences
            )
    
    print(f"User : {username} added to the database")

def search_face_in_db(
                    img_path, 
                    face_index_path = 'models/face_index',
                    face_details_path = 'models/face_details.npz',
                    ):
    index, user_names, _, _ = build_face_embedding_index(
                                                        face_index_path = face_index_path,
                                                        face_details_path = face_details_path,
                                                        )
    embeddings, face_confidences, facial_areas = extract_face_information_for_inference(img_path)

    retrieved_user_names = []
    retrieved_facial_areas = []
    retrieved_face_confidences = []

    if embeddings is not None:
        for idx, emb in enumerate(embeddings):
            if face_confidences[idx] >= 0.8:
                emb = np.array(emb).reshape(1, -1).astype('float32')
                faiss.normalize_L2(emb)
                D, I = index.search(emb, 5)
                I = np.array(I).squeeze()
                D = np.array(D).squeeze()
                user_name_list = [user_names[i] for i in I]
                user_name = max(set(user_name_list), key = user_name_list.count)
                avg_confidence = np.mean([d for i, d in zip(I, D) if user_names[i] == user_name])
                retrieved_face_confidences.append(np.round(avg_confidence, 3))
                retrieved_facial_areas.append(facial_areas[idx])
                retrieved_user_names.append(user_name)

    return retrieved_user_names, retrieved_facial_areas, retrieved_face_confidences

def verify_and_visualize_user(  
                                username,
                                img_path,
                                ):
    retrieved_user_names, retrieved_facial_areas, retrieved_face_confidences = search_face_in_db(img_path)

    image = Image.open(img_path)
    draw = ImageDraw.Draw(image)

    for i in range(len(retrieved_user_names)):
        x, y, w, h = retrieved_facial_areas[i]
        face_area = w * h
        if (face_area >= 20000):
            if (retrieved_user_names[i] == username) and (retrieved_face_confidences[i] >= 0.5):
                draw.rectangle([x, y, x+w, y+h], outline='green', width=5)
                font = ImageFont.truetype("arial.ttf", 30)
                draw.text((x-30, y-70), f'User: {retrieved_user_names[i]}', font=font, fill='green')
            else:
                draw.rectangle([x, y, x+w, y+h], outline='red', width=5)
                font = ImageFont.truetype("arial.ttf", 30)

    plt.imshow(image)
    plt.show()

def verify_and_visualize_user_realtime(username):
    cap = cv.VideoCapture(0)
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        cv.imwrite("data/temp_dir/temp.jpg", frame)
        
        retrieved_user_names, retrieved_facial_areas, retrieved_face_confidences = search_face_in_db("data/temp_dir/temp.jpg")
        for i in range(len(retrieved_user_names)):
            x, y, w, h = retrieved_facial_areas[i]
            face_area = w * h
            if (face_area >= 20000):
                if (retrieved_user_names[i] == username) and (retrieved_face_confidences[i] >= 0.5):
                    cv.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
                    font = cv.FONT_HERSHEY_SIMPLEX
                    cv.putText(frame, f'User: {retrieved_user_names[i]}', (x-30, y-40), font, 1, (0, 255, 0), 2)
                else:
                    cv.rectangle(frame, (x, y), (x+w, y+h), (0, 0, 255), 2)

        cv.imshow('frame', frame)

        if cv.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv.destroyAllWindows()

# %%
add_user_to_db('purna')

# %%
retrieved_user_names, retrieved_facial_areas, retrieved_face_confidences = search_face_in_db(img_path)

print(f"Retrieve User Names : {retrieved_user_names}")
print(f"Retrieve Face Confidences : {retrieved_face_confidences}")
print(f"Retrieve Facial Areas : {retrieved_facial_areas}")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 retrieved_user_names, retrieved_facial_areas, retrieved_face_confidences = search_face_in_db(img_path)
#       3 print(f"Retrieve User Names : {retrieved_user_names}")
#       4 print(f"Retrieve Face Confidences : {retrieved_face_confidences}")
#
# Cell In[9], line 65, in search_face_in_db(img_path, face_index_path, face_details_path)
#      63 emb = np.array(emb).reshape(1, -1).astype('float32')
#      64 faiss.normalize_L2(emb)
# ---> 65 D, I = index.search(emb, 5)
#      66 I = np.array(I).squeeze()
#      67 D = np.array(D).squeeze()
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\faiss\class_wrappers.py:329, in handle_Index.<locals>.replacement_search(self, x, k, params, D, I)
#     327 n, d = x.shape
#     328 x = np.ascontiguousarray(x, dtype='float32')
# --> 329 assert d == self.d
#     331 assert k > 0
#     333 if D is None:
#
# AssertionError:

# %%
verify_and_visualize_user("purna", 'data/test_images/purna (11).jpg')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 verify_and_visualize_user("purna", 'data/test_images/purna (11).jpg')
#
# Cell In[45], line 81, in verify_and_visualize_user(username, img_path)
#      77 def verify_and_visualize_user(
#      78                                 username,
#      79                                 img_path,
#      80                                 ):
# ---> 81     retrieved_user_names, retrieved_facial_areas, retrieved_face_confidences = search_face_in_db(img_path)
#      83     image = Image.open(img_path)
#      84     draw = ImageDraw.Draw(image)
#
# Cell In[45], line 65, in search_face_in_db(img_path, face_index_path, face_details_path)
#      63 emb = np.array(emb).reshape(1, -1).astype('float32')
#      64 faiss.normalize_L2(emb)
# ---> 65 D, I = index.search(emb, 5)
#      66 I = np.array(I).squeeze()
#      67 D = np.array(D).squeeze()
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\faiss\class_wrappers.py:329, in handle_Index.<locals>.replacement_search(self, x, k, params, D, I)
#     327 n, d = x.shape
#     328 x = np.ascontiguousarray(x, dtype='float32')
# --> 329 assert d == self.d
#     331 assert k > 0
#     333 if D is None:
#
# AssertionError:

# %%
verify_and_visualize_user_realtime("purna")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 verify_and_visualize_user_realtime("purna")
#
# NameError: name 'verify_and_visualize_user_realtime' is not defined
