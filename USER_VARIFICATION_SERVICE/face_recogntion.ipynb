# %%
import cv2 as cv
import glob, json
import numpy as np
import faiss, glob, os
import tensorflow as tf
from deepface import DeepFace
from matplotlib import pyplot as plt
from PIL import Image, ImageDraw, ImageFont

# %%
models = [
        "VGG-Face", 
        "Facenet", 
        "OpenFace", 
        "DeepFace", 
        "DeepID", 
        "ArcFace", 
        "Dlib", 
        "SFace",
        "GhostFaceNet",
        ]

# %%
def create_dataset(
                data_dir = "data/facedb/*/*.*",
                json_dir = "data/facedb_jsons/{}/{}",
                ):
    for img_path in glob.glob(data_dir):
        person_objs = []
        img_path = img_path.replace("\\", "/")
        person_name = img_path.split("/")[-2]
        file_name = img_path.split("/")[-1]
        face_objs = DeepFace.represent(
                                    img_path = img_path,
                                    model_name = "Facenet512",
                                    enforce_detection = False
                                    )
        if len(face_objs) > 0:
            for i in range(len(face_objs)):
                person_json = {}
                facial_area = face_objs[i]['facial_area']
                x, y, w, h = facial_area['x'], facial_area['y'], facial_area['w'], facial_area['h']
                person_json['person_name'] = person_name
                person_json['facial_area'] = facial_area
                person_json['file_name'] = file_name
                person_json['coor'] = (x, y, w, h)
                person_objs.append(person_json)

        if len(person_objs) > 0:
            os.makedirs(json_dir.format(person_name, ""), exist_ok=True)
            json_file = json_dir.format(person_name, file_name.replace(".jpg", ".json"))
            with open(json_file, 'w') as json_file:
                json.dump(person_objs, json_file)

# %%
create_dataset()

# %% [markdown]
# ### Detection Model

# %%
def load_detection_dataset(
                            data_dir = "data/facedb/*/*.*"
                            ):
    X, Y = [], []
    for img_path in glob.glob(data_dir):
        json_path = img_path.replace("\\", "/").replace("facedb", "facedb_jsons").replace(".jpg", ".json")
        if (os.path.exists(json_path)):
            with open(json_path, 'r') as json_file:
                json_data = json.load(json_file)
                person = json_data[0]
                x, y, w, h = person['coor']
                img = cv.imread(img_path)
                img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
                img = cv.resize(img, (128, 128))

                X.append(img)
                Y.append((x, y, w, h))

    return np.array(X), np.array(Y)

# %%
X, Y = load_detection_dataset() 

print("Image Shape: ", X.shape)
print("Label Shape: ", Y.shape)
# Out:
# Image Shape:  (395, 128, 128, 3)
# Label Shape:  (395, 4)

# %%
model = tf.keras.models.Sequential([
                                    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
                                    tf.keras.layers.MaxPooling2D((2, 2)),
                                    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
                                    tf.keras.layers.MaxPooling2D((2, 2)),
                                    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
                                    tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(64, activation='relu'),
                                    tf.keras.layers.Dense(4)
                                    ])

model.compile(
                optimizer='adam', 
                loss='mean_squared_error', 
                metrics=['mae']
                )
model.fit(
        X, Y, 
        epochs=200
        )
# Out:
# Epoch 1/200
# 13/13 [==============================] - 4s 259ms/step - loss: 353295.2188 - mae: 388.3157
# Epoch 2/200
# 13/13 [==============================] - 3s 264ms/step - loss: 150382.9844 - mae: 268.1122
# Epoch 3/200
# 13/13 [==============================] - 3s 260ms/step - loss: 144860.4375 - mae: 276.4159
# Epoch 4/200
# 13/13 [==============================] - 4s 292ms/step - loss: 138291.6875 - mae: 261.9161
# Epoch 5/200
# 13/13 [==============================] - 4s 291ms/step - loss: 123131.7188 - mae: 245.8247
# Epoch 6/200
# 13/13 [==============================] - 4s 274ms/step - loss: 104581.2656 - mae: 235.3490
# Epoch 7/200
# 13/13 [==============================] - 4s 301ms/step - loss: 86064.0312 - mae: 205.6735
# Epoch 189/200
# 13/13 [==============================] - 4s 269ms/step - loss: 79.7210 - mae: 6.2479
# Epoch 190/200
# 13/13 [==============================] - 4s 274ms/step - loss: 81.0474 - mae: 6.3262
# Epoch 191/200
# 13/13 [==============================] - 4s 274ms/step - loss: 99.1252 - mae: 7.0661
# Epoch 192/200
# 13/13 [==============================] - 4s 276ms/step - loss: 151.3913 - mae: 8.6879
# Epoch 193/200
# 13/13 [==============================] - 4s 278ms/step - loss: 319.9320 - mae: 12.4467
# Epoch 194/200
# 13/13 [==============================] - 4s 280ms/step - loss: 782.9154 - mae: 21.0073
# Epoch 195/200
# 13/13 [==============================] - 4s 285ms/step - loss: 1134.7421 - mae: 23.8224
# Epoch 196/200
# 13/13 [==============================] - 4s 286ms/step - loss: 2147.4939 - mae: 32.8735
# Epoch 197/200
# 13/13 [==============================] - 4s 279ms/step - loss: 3749.6711 - mae: 42.6269
# Epoch 198/200
# 13/13 [==============================] - 4s 279ms/step - loss: 3104.0259 - mae: 40.3187
# Epoch 199/200
# 13/13 [==============================] - 4s 283ms/step - loss: 3547.0269 - mae: 41.1314
# Epoch 200/200
# 13/13 [==============================] - 4s 273ms/step - loss: 4662.3174 - mae: 49.0000

# %%
def visualize_face_detection(img_path):
    face_objs = DeepFace.represent(
                                img_path = img_path,
                                model_name = "Facenet512",
                                enforce_detection = False
                                )
    for i in range(len(face_objs)):
        facial_area = face_objs[i]['facial_area']
        face_confidence = face_objs[i]['face_confidence']
        x, y, w, h = facial_area['x'], facial_area['y'], facial_area['w'], facial_area['h']

        image = Image.open(img_path)
        draw = ImageDraw.Draw(image)
        draw.rectangle([x, y, x+w, y+h], outline='red', width=5)
        font = ImageFont.truetype("arial.ttf", 30)
        draw.text((x-30, y-40), f'Confidence: {face_confidence}', font=font, fill='blue')
        
    plt.imshow(image)

# %%
img_dir = "data/facedb/wijenandana"
for img_path in glob.glob(f"{img_dir}/*.*"):
    visualize_face_detection(img_path)
    plt.show()

# %%
def extract_face_information_for_db(img_path):
    # face_objs = DeepFace.represent(
    #                                 img_path = img_path, 
    #                                 detector_backend = backends[4],
    #                                 align = alignment_modes[0],
    #                                 enforce_detection = False
    #                                 )
    face_objs = DeepFace.represent(
                                img_path = img_path,
                                model_name = models[2],
                                enforce_detection = False
                                )
    img_path = img_path.replace("\\", "/")
    user_name = img_path.split("/")[-2]

    if len(face_objs) != 1:
        if len(face_objs) == 0:
            Warning(f"No faces detected in the image : {img_path}")
        else:
            Warning(f"Multiple faces detected in the image : {img_path}")
        return None, None, None, None

    else:
        facial_area = face_objs[0]['facial_area']
        embeddings = face_objs[0]['embedding']
        print(f"Embedding dimension for {img_path}: {len(embeddings)}")
        face_confidence = face_objs[0]['face_confidence']
        x, y, w, h = facial_area['x'], facial_area['y'], facial_area['w'], facial_area['h']

    return embeddings, face_confidence, (x, y, w, h), user_name

def extract_face_information_for_inference(img_path):
    face_objs = DeepFace.represent(
                                img_path = img_path,
                                model_name = models[2],
                                enforce_detection = False
                                )
    img_path = img_path.replace("\\", "/")

    embeddings = []
    facial_areas = []
    face_confidences = []

    if len(face_objs) == 0:
        Warning(f"No faces detected in the image : {img_path}")
    else:
        for i in range(len(face_objs)):
            embs = face_objs[i]['embedding']
            facial_area = face_objs[i]['facial_area']
            face_confidence = face_objs[i]['face_confidence']
            x, y, w, h = facial_area['x'], facial_area['y'], facial_area['w'], facial_area['h']

            embeddings.append(embs)
            facial_areas.append((x, y, w, h))   
            face_confidences.append(face_confidence)

    return embeddings, face_confidences, facial_areas

# %%
def build_face_embedding_index(
                                d = 128,
                                face_index_path = 'models/face_index',
                                face_image_dir = 'data/facedb/*/*.jpg',
                                face_details_path = 'models/face_details.npz',
                                ):
    if (not os.path.exists(face_index_path)) or (not os.path.exists(face_details_path)):
        faiss_index = faiss.index_factory(d, "Flat", faiss.METRIC_INNER_PRODUCT)

        embeddings = []
        user_names = []
        facial_areas = []
        face_confidences = []
        
        for idx, img_path in enumerate(glob.glob(face_image_dir)):
            emb, face_confidence, facial_area, user_name = extract_face_information_for_db(img_path)
            if emb is not None:
                embeddings.append(emb)
                user_names.append(user_name)
                facial_areas.append(facial_area)
                face_confidences.append(face_confidence)

            if idx % 10 == 0:
                print(f"Processed {idx}/{len(glob.glob(face_image_dir))} images")

        embeddings = np.asarray(embeddings).astype('float32')
        faiss.normalize_L2(embeddings)
        faiss_index.add(embeddings)
        faiss.write_index(faiss_index, face_index_path)

        np.savez(
                face_details_path, 
                user_names=user_names, 
                facial_areas=facial_areas, 
                face_confidences=face_confidences
                )
        
    else:
        faiss_index = faiss.read_index(face_index_path)
        face_details = np.load(face_details_path)
        user_names = face_details['user_names']
        facial_areas = face_details['facial_areas']
        face_confidences = face_details['face_confidences']

    return faiss_index, user_names, facial_areas, face_confidences

# %%
index, user_names, facial_areas, face_confidences = build_face_embedding_index()

# %%
def add_user_to_db(
                    username, 
                    face_index_path = 'models/face_index',
                    face_details_path = 'models/face_details.npz',
                    face_image_dir = 'data/facedb/{}/*.jpg'
                    ):
    index, user_names, facial_areas, face_confidences = build_face_embedding_index(
                                                                                    face_index_path = face_index_path,
                                                                                    face_details_path = face_details_path,
                                                                                    )
    if username in user_names:
        Warning(f"User {username} already exists in the database")
        return
    
    user_names_to_add = []
    facial_areas_to_add = []
    face_confidences_to_add = []

    for img_path in glob.glob(face_image_dir.format(username)):
        emb, face_confidence, facial_area, user_name = extract_face_information_for_db(img_path)
        if emb is not None:
            embeddings = np.array([emb]).astype('float32')
            faiss.normalize_L2(embeddings)
            index.add(embeddings)
            user_names_to_add.append(user_name)
            facial_areas_to_add.append(facial_area)
            face_confidences_to_add.append(face_confidence)

    faiss.write_index(index, face_index_path)

    if len(user_names_to_add) > 0:
        user_names = np.concatenate([user_names, user_names_to_add])
        facial_areas = np.concatenate([facial_areas, facial_areas_to_add])
        face_confidences = np.concatenate([face_confidences, face_confidences_to_add])

    np.savez(
            face_details_path, 
            user_names=user_names, 
            facial_areas=facial_areas, 
            face_confidences=face_confidences
            )
    
    print(f"User : {username} added to the database")

def search_face_in_db(
                    img_path, 
                    face_index_path = 'models/face_index',
                    face_details_path = 'models/face_details.npz',
                    ):
    index, user_names, _, _ = build_face_embedding_index(
                                                        face_index_path = face_index_path,
                                                        face_details_path = face_details_path,
                                                        )
    embeddings, face_confidences, facial_areas = extract_face_information_for_inference(img_path)

    retrieved_user_names = []
    retrieved_facial_areas = []
    retrieved_face_confidences = []

    if embeddings is not None:
        for idx, emb in enumerate(embeddings):
            if face_confidences[idx] >= 0.8:
                emb = np.array(emb).reshape(1, -1).astype('float32')
                faiss.normalize_L2(emb)
                D, I = index.search(emb, 5)
                I = np.array(I).squeeze()
                D = np.array(D).squeeze()
                user_name_list = [user_names[i] for i in I]
                user_name = max(set(user_name_list), key = user_name_list.count)
                avg_confidence = np.mean([d for i, d in zip(I, D) if user_names[i] == user_name])
                retrieved_face_confidences.append(np.round(avg_confidence, 3))
                retrieved_facial_areas.append(facial_areas[idx])
                retrieved_user_names.append(user_name)

    return retrieved_user_names, retrieved_facial_areas, retrieved_face_confidences

def verify_and_visualize_user(  
                                username,
                                img_path,
                                ):
    retrieved_user_names, retrieved_facial_areas, retrieved_face_confidences = search_face_in_db(img_path)

    image = Image.open(img_path)
    draw = ImageDraw.Draw(image)

    for i in range(len(retrieved_user_names)):
        x, y, w, h = retrieved_facial_areas[i]
        face_area = w * h
        if (face_area >= 20000):
            if (retrieved_user_names[i] == username) and (retrieved_face_confidences[i] >= 0.5):
                draw.rectangle([x, y, x+w, y+h], outline='green', width=5)
                font = ImageFont.truetype("arial.ttf", 30)
                draw.text((x-30, y-70), f'User: {retrieved_user_names[i]}', font=font, fill='green')
            else:
                draw.rectangle([x, y, x+w, y+h], outline='red', width=5)
                font = ImageFont.truetype("arial.ttf", 30)

    plt.imshow(image)
    plt.show()

def verify_and_visualize_user_realtime(username):
    cap = cv.VideoCapture(0)
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        cv.imwrite("data/temp_dir/temp.jpg", frame)
        
        retrieved_user_names, retrieved_facial_areas, retrieved_face_confidences = search_face_in_db("data/temp_dir/temp.jpg")
        for i in range(len(retrieved_user_names)):
            x, y, w, h = retrieved_facial_areas[i]
            face_area = w * h
            if (face_area >= 20000):
                if (retrieved_user_names[i] == username) and (retrieved_face_confidences[i] >= 0.5):
                    cv.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
                    font = cv.FONT_HERSHEY_SIMPLEX
                    cv.putText(frame, f'User: {retrieved_user_names[i]}', (x-30, y-40), font, 1, (0, 255, 0), 2)
                else:
                    cv.rectangle(frame, (x, y), (x+w, y+h), (0, 0, 255), 2)

        cv.imshow('frame', frame)

        if cv.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv.destroyAllWindows()

# %%
add_user_to_db('wijenandana')
# Out:
# Embedding dimension for data/facedb/wijenandana/wijenandana (1).jpg: 128
# Embedding dimension for data/facedb/wijenandana/wijenandana (4).jpg: 128
# Embedding dimension for data/facedb/wijenandana/wijenandana (5).jpg: 128
# Embedding dimension for data/facedb/wijenandana/wijenandana (6).jpg: 128
# Embedding dimension for data/facedb/wijenandana/wijenandana (7).jpg: 128
# Embedding dimension for data/facedb/wijenandana/wijenandana (8).jpg: 128
# User : wijenandana added to the database

# %%
img_dir = "data/facedb/wijenandana"
for img_path in glob.glob(f"{img_dir}/*.*"):
    retrieved_user_names, retrieved_facial_areas, retrieved_face_confidences = search_face_in_db(img_path)

    print(f"Retrieve User Names : {retrieved_user_names}")
    print(f"Retrieve Face Confidences : {retrieved_face_confidences}")
    print(f"Retrieve Facial Areas : {retrieved_facial_areas}")
# Out:
# Retrieve User Names : ['wijenandana']
# Retrieve Face Confidences : [0.09]
# Retrieve Facial Areas : [(309, 1064, 1992, 1992)]
# Retrieve User Names : ['wijenandana']
# Retrieve Face Confidences : [0.059]
# Retrieve Facial Areas : [(607, 1088, 1881, 1881)]
# Retrieve User Names : ['sasida']
# Retrieve Face Confidences : [0.247]
# Retrieve Facial Areas : [(519, 1070, 1618, 1618)]
# Retrieve User Names : ['wijenandana']
# Retrieve Face Confidences : [0.05]
# Retrieve Facial Areas : [(412, 1071, 2096, 2096)]
# Retrieve User Names : ['wijenandana']
# Retrieve Face Confidences : [0.069]
# Retrieve Facial Areas : [(367, 913, 2194, 2194)]
# Retrieve User Names : ['wijenandana']
# Retrieve Face Confidences : [0.084]
# Retrieve Facial Areas : [(355, 1000, 2379, 2379)]
# Retrieve User Names : ['wijenandana', 'Amitabh Bachchan']
# Retrieve Face Confidences : [0.196, 1.0]
# Retrieve Facial Areas : [(737, 872, 1654, 1654), (1226, 3782, 114, 114)]

# %%
verify_and_visualize_user("wijenandana", 'data/test_images/wijenandana (5).jpg')

# %%
verify_and_visualize_user_realtime("wijenandana")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 verify_and_visualize_user_realtime("wijenandana")
#
# Cell In[9], line 110, in verify_and_visualize_user_realtime(username)
#     106     break
#     108 cv.imwrite("data/temp_dir/temp.jpg", frame)
# --> 110 retrieved_user_names, retrieved_facial_areas, retrieved_face_confidences = search_face_in_db("data/temp_dir/temp.jpg")
#     111 for i in range(len(retrieved_user_names)):
#     112     x, y, w, h = retrieved_facial_areas[i]
#
# Cell In[9], line 54, in search_face_in_db(img_path, face_index_path, face_details_path)
#      45 def search_face_in_db(
#      46                     img_path,
#      47                     face_index_path = 'models/face_index',
#      48                     face_details_path = 'models/face_details.npz',
#      49                     ):
#      50     index, user_names, _, _ = build_face_embedding_index(
#      51                                                         face_index_path = face_index_path,
#      52                                                         face_details_path = face_details_path,
#      53                                                         )
# ---> 54     embeddings, face_confidences, facial_areas = extract_face_information_for_inference(img_path)
#      56     retrieved_user_names = []
#      57     retrieved_facial_areas = []
#
# Cell In[11], line 33, in extract_face_information_for_inference(img_path)
#      32 def extract_face_information_for_inference(img_path):
# ---> 33     face_objs = DeepFace.represent(
#      34                                 img_path = img_path,
#      35                                 model_name = models[2],
#      36                                 enforce_detection = False
#      37                                 )
#      38     img_path = img_path.replace("\\", "/")
#      40     embeddings = []
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\deepface\DeepFace.py:418, in represent(img_path, model_name, enforce_detection, detector_backend, align, expand_percentage, normalization, anti_spoofing, max_faces)
#     359 def represent(
#     360     img_path: Union[str, np.ndarray],
#     361     model_name: str = "VGG-Face",
#    (...)
#     368     max_faces: Optional[int] = None,
#     369 ) -> List[Dict[str, Any]]:
#     370     """
#     371     Represent facial images as multi-dimensional vector embeddings.
#     372
#    (...)
#     416             to 'skip', the confidence will be 0 and is nonsensical.
#     417     """
# --> 418     return representation.represent(
#     419         img_path=img_path,
#     420         model_name=model_name,
#     421         enforce_detection=enforce_detection,
#     422         detector_backend=detector_backend,
#     423         align=align,
#     424         expand_percentage=expand_percentage,
#     425         normalization=normalization,
#     426         anti_spoofing=anti_spoofing,
#     427         max_faces=max_faces,
#     428     )
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\deepface\modules\representation.py:133, in represent(img_path, model_name, enforce_detection, detector_backend, align, expand_percentage, normalization, anti_spoofing, max_faces)
#     130     # custom normalization
#     131     img = preprocessing.normalize_input(img=img, normalization=normalization)
# --> 133     embedding = model.forward(img)
#     135     resp_objs.append(
#     136         {
#     137             "embedding": embedding,
#    (...)
#     140         }
#     141     )
#     143 return resp_objs
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\deepface\models\FacialRecognition.py:29, in FacialRecognition.forward(self, img)
#      23     raise ValueError(
#      24         "You must overwrite forward method if it is not a keras model,"
#      25         f"but {self.model_name} not overwritten!"
#      26     )
#      27 # model.predict causes memory issue when it is called in a for loop
#      28 # embedding = model.predict(img, verbose=0)[0].tolist()
# ---> 29 return self.model(img, training=False).numpy()[0].tolist()
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\keras\engine\training.py:557, in Model.__call__(self, *args, **kwargs)
#     553         super().__call__(inputs, *copied_args, **copied_kwargs)
#     555     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 557 return super().__call__(*args, **kwargs)
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\keras\engine\base_layer.py:1097, in Layer.__call__(self, *args, **kwargs)
#    1092     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1094 with autocast_variable.enable_auto_cast_variables(
#    1095     self._compute_dtype_object
#    1096 ):
# -> 1097     outputs = call_fn(inputs, *args, **kwargs)
#    1099 if self._activity_regularizer:
#    1100     self._handle_activity_regularization(inputs, outputs)
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\keras\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\keras\engine\functional.py:510, in Functional.call(self, inputs, training, mask)
#     491 @doc_controls.do_not_doc_inheritable
#     492 def call(self, inputs, training=None, mask=None):
#     493     """Calls the model on new inputs.
#     494
#     495     In this case `call` just reapplies
#    (...)
#     508         a list of tensors if there are more than one outputs.
#     509     """
# --> 510     return self._run_internal_graph(inputs, training=training, mask=mask)
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\keras\engine\functional.py:667, in Functional._run_internal_graph(self, inputs, training, mask)
#     664     continue  # Node is not computable, try skipping.
#     666 args, kwargs = node.map_arguments(tensor_dict)
# --> 667 outputs = node.layer(*args, **kwargs)
#     669 # Update tensor_dict.
#     670 for x_id, y in zip(
#     671     node.flat_output_ids, tf.nest.flatten(outputs)
#     672 ):
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\keras\engine\base_layer.py:1097, in Layer.__call__(self, *args, **kwargs)
#    1092     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1094 with autocast_variable.enable_auto_cast_variables(
#    1095     self._compute_dtype_object
#    1096 ):
# -> 1097     outputs = call_fn(inputs, *args, **kwargs)
#    1099 if self._activity_regularizer:
#    1100     self._handle_activity_regularization(inputs, outputs)
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\keras\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\keras\layers\normalization\batch_normalization.py:850, in BatchNormalizationBase.call(self, inputs, training)
#     847         return outputs
#     849 if self.fused:
# --> 850     outputs = self._fused_batch_norm(inputs, training=training)
#     851     if self.virtual_batch_size is not None:
#     852         # Currently never reaches here since fused_batch_norm does not
#     853         # support virtual batching
#     854         outputs = undo_virtual_batching(outputs)
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\keras\layers\normalization\batch_normalization.py:660, in BatchNormalizationBase._fused_batch_norm(self, inputs, training)
#     648 def _fused_batch_norm_inference():
#     649     return tf.compat.v1.nn.fused_batch_norm(
#     650         inputs,
#     651         gamma,
#    (...)
#     657         data_format=self._data_format,
#     658     )
# --> 660 output, mean, variance = control_flow_util.smart_cond(
#     661     training, _fused_batch_norm_training, _fused_batch_norm_inference
#     662 )
#     663 variance = _maybe_add_or_remove_bessels_correction(
#     664     variance, remove=True
#     665 )
#     667 training_value = control_flow_util.constant_value(training)
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\keras\utils\control_flow_util.py:108, in smart_cond(pred, true_fn, false_fn, name)
#     106 if isinstance(pred, tf.Variable):
#     107     return tf.cond(pred, true_fn=true_fn, false_fn=false_fn, name=name)
# --> 108 return tf.__internal__.smart_cond.smart_cond(
#     109     pred, true_fn=true_fn, false_fn=false_fn, name=name
#     110 )
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\tensorflow\python\framework\smart_cond.py:54, in smart_cond(pred, true_fn, false_fn, name)
#      52     return true_fn()
#      53   else:
# ---> 54     return false_fn()
#      55 else:
#      56   return control_flow_ops.cond(pred, true_fn=true_fn, false_fn=false_fn,
#      57                                name=name)
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\keras\layers\normalization\batch_normalization.py:649, in BatchNormalizationBase._fused_batch_norm.<locals>._fused_batch_norm_inference()
#     648 def _fused_batch_norm_inference():
# --> 649     return tf.compat.v1.nn.fused_batch_norm(
#     650         inputs,
#     651         gamma,
#     652         beta,
#     653         mean=self.moving_mean,
#     654         variance=self.moving_variance,
#     655         epsilon=self.epsilon,
#     656         is_training=False,
#     657         data_format=self._data_format,
#     658     )
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\tensorflow\python\ops\nn_impl.py:1679, in fused_batch_norm(x, scale, offset, mean, variance, epsilon, data_format, is_training, name, exponential_avg_factor)
#    1674   raise ValueError("Both `mean` and `variance` must be a 1D tensor when "
#    1675                    "`is_training` is False or `exponential_avg_factor` != "
#    1676                    f"1.0. Received: `mean` {mean!r} and `variance` "
#    1677                    f"{variance!r}")
#    1678 x = ops.convert_to_tensor(x, name="input")
# -> 1679 scale = ops.convert_to_tensor(scale, name="scale")
#    1680 offset = ops.convert_to_tensor(offset, name="offset")
#    1681 if mean is None:
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\tensorflow\python\framework\ops.py:1638, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1629       raise RuntimeError(
#    1630           _add_error_prefix(
#    1631               f"Conversion function {conversion_func!r} for type "
#    (...)
#    1634               f"actual = {ret.dtype.base_dtype.name}",
#    1635               name=name))
#    1637 if ret is None:
# -> 1638   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1640 if ret is NotImplemented:
#    1641   continue
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:2105, in _dense_var_to_tensor(var, dtype, name, as_ref)
#    2104 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 2105   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1467, in BaseResourceVariable._dense_var_to_tensor(***failed resolving arguments***)
#    1465   return self.read_value().op.inputs[0]
#    1466 else:
# -> 1467   return self.value()
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:582, in BaseResourceVariable.value(self)
#     580   return self._cached_value
#     581 with ops.colocate_with(None, ignore_existing=True):
# --> 582   return self._read_variable_op()
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:704, in BaseResourceVariable._read_variable_op(self, no_copy)
#     702       result = read_and_set_handle(no_copy)
#     703 else:
# --> 704   result = read_and_set_handle(no_copy)
#     706 if not context.executing_eagerly():
#     707   # Note that if a control flow context is active the input of the read op
#     708   # might not actually be the handle. This line bypasses it.
#     709   tape.record_operation(
#     710       "ReadVariableOp", [result], [self.handle],
#     711       backward_function=lambda x: [x],
#     712       forward_function=lambda x: [x])
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:694, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     692 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     693   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 694 result = gen_resource_variable_ops.read_variable_op(
#     695     self.handle, self._dtype)
#     696 _maybe_set_handle_data(self._dtype, self.handle, result)
#     697 return result
#
# File c:\Users\purna\.conda\envs\elearning\lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:524, in read_variable_op(resource, dtype, name)
#     522 if tld.is_eager:
#     523   try:
# --> 524     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     525       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     526     return _result
#     527   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
